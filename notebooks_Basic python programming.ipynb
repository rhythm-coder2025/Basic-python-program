# %%
import numpy as np
x = 3.14
y = np.sin(x)
print(y)
# Out:
# 0.0015926529164868282

# %%
import numpy as np
import math as mt
x = 3.14
y = np.sin(x)
print(y)
y = mt.sin(x)
print(y)
# Out:
# 0.0015926529164868282
# 0.0015926529164868282

# %%
from math import *
from numpy import *
x = 3
y = sin(x)
print(y)
y = cos(x)
print(y)
# Out:
# 0.1411200080598672
# -0.9899924966004454

# %%
from matplotlib.pyplot import *
x =[1,2,3,4,5,6,7,8]
y =[9,1.1,1.4,12,13,9,2,1]
plot (x,y)
xlabel("Time (s)")
ylabel("Temperature (degC)")
show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = [1,2,0,1,1.1,7,3.5,7.7]
y = np.sin(x)
plt.plot(x,y)
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
xstart = 0
xstop = 2*np.pi
increment = 0.1
x = np.arange(xstart, xstop, increment)
y = np.sin(x)
plt.plot(x,y)
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xstart = 0
xstop = 2*np.pi
increment = 0.1

x = np.arange(xstart, xstop, increment)
y = np.sin(x)
z = np.cos(x)

plt.subplot(2,1,1)
plt.plot(x,y, "g")
plt.title("sin")
plt.xlabel("x")
plt.ylabel("sin(x)")
plt.grid()
plt.show()

plt.subplot(2,1,2)
plt.plot(x,z, "r")
plt.title("cos")
plt.xlabel("x")
plt.ylabel("cos(x)")
plt.grid()
plt.show()
